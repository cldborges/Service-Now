# %%
import pandas as pd

linha = int(input('Qual a linha?: ') ) - 2

df = pd.read_excel('teste.xlsm')
df = df.drop(['Cod_Category', 'Cod_Category2', 'Cod_Category3', 'Template', ], axis='columns')

# %%
category = df.loc[linha, 'Category']
subcategory = df.loc[linha, 'Subcategory']
subsubcategory = df.loc[linha, 'Subsubcategory']
short_description = df.loc[linha, 'Short Description']
description = df.loc[linha, 'Description']
tipo = df.loc[linha, 'Tipo']
if pd.isnull(tipo):
    tipo = 'Incident'

print(category, subcategory, subsubcategory)
print(short_description)
print(description)
print(tipo)
# Out:
# Workplace DWP Win 10 Local Client File Share Encryption
# Arquivos na rede corrompendo
# Usuário informa que ao abrir ou salvar arquivos em pastas de rede criptografadas o arquivo não abre ou é corrompido.
# Incident

# %%
display(df)
# Out:
#      Utilizações                             Problema Costumer Identification  \
# 0            NaN         Verificação de pacote Office                z004f0cr
# 1            7.0        Office faltando depois do ZTI                z004f0cr
# 2          126.0                      #ZTI não inicia                z004f0cr
# 3            7.0          PKI não funciona - Hardware                Z0045k6d
# 4            1.0          Não consegue imprimir - PKI                Z003X7ZF
# ..           ...                                  ...                     ...
# 165          1.0     Não conecta em redes não-Siemens                     NaN
# 166          1.0  Problema com sincronização do TEAMS                     NaN
# 167          1.0      Não consegue logar no #Software                     NaN
# 168          1.0     Ajuda para fazer login no Chrome                     NaN
# 169          1.0              Habilitar Windows Hello                     NaN
#
#               Category                         Subcategory  \
# 0             Software          Managed Software Workplace
# 1             Software          Managed Software Workplace
# 2            Workplace             DWP Win 10 Local Client
# 3            Workplace                     Client Hardware
# 4    Output Management                     OMS Print Ricoh
# ..                 ...                                 ...
# 165            Network  Wireless Local Area Network (WLAN)
# 166           Software          Managed Software Workplace
# 167           Software          Managed Software Workplace
# 168           Software          Managed Software Workplace
# 169          Workplace             DWP Win 10 Local Client
#
#                     Subsubcategory                     Short Description  \
# 0         O365 Installation Issues          Verificação de pacote Office
# 1         O365 Installation Issues            Sem pacote Office após ZTI
# 2    ZTI - Zero Touch Installation                        ZTI não inicia
# 3                  PC as a service                      PKI não funciona
# 4               PKI Authentication                 Não consegue imprimir
# ..                             ...                                   ...
# 165             Connectivity (WAN)      Não conecta em redes não-Siemens
# 166              Standard Software  Problemas com sincronização do TEAMS
# 167              Standard Software       Não consegue logar no #Software
# 168              Standard Software                       Login no Chrome
# 169             System Performance               Habilitar Windows Hello
#
#                                            Description  \
# 0    Usuário realizou o ZTI no equipamento e solici...
# 1    Usuário informa que ao logar em sua máquina ap...
# 2       Usuário informa que não consegue iniciar o ZTI
# 3    Usuário informa que ao encaixar o crachá em se...
# 4    Usuário informa que não consegue imprimir - Er...
# ..                                                 ...
# 165  Usuário informa que não consegue conectar-se à...
# 166  Usuário informa que ás vezes recebe mensagens ...
# 167  Usuário informa ter problemas para efetuar o l...
# 168  Usuário solicita ajuda para fazer o login de s...
# 169  Usuário solicita ajuda para habilitar o Window...
#
#                                            Data Points             Tipo
# 0                                                  NaN         Incident
# 1                                                  NaN         Incident
# 2    IMPORTANT: DO NOT DELETE ANY TEXT BELOW, JUST ...         Incident
# 3                                                  NaN         Incident
# 4                                                  NaN         Incident
# ..                                                 ...              ...
# 165  IMPORTANT: Please gather the following MANDATO...         Incident
# 166                 Affected Software: mentioned above         Incident
# 167                 Affected Software: mentioned above         Incident
# 168                 Affected Software: mentioned above  Service Request
# 169  IMPORTANT: DO NOT DELETE ANY TEXT BELOW, JUST ...  Service Request
#
# [170 rows x 10 columns]
